# %% [markdown]
# ## **Importing libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import plotly.express as px

# %% [markdown]
# ## **Loading dataset from kaggle**

# %%
df=pd.read_csv('C:\Github repos\Pakistan data analysis\Pakistan-population-Data-anlaysis\sub-division_population_of_pakistan.csv')

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
import ydata_profiling
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Profiling Report")

# %%
profile.to_file("your_report.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 15.00it/s]

# %% [markdown]
# ## **Checking missing values**

# %%
df.isnull().sum()
# Out:
# PROVINCE                      0
# DIVISION                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64

# %% [markdown]
# ## **Shape of the dataset**

# %%
df.shape
# Out:
# (528, 21)

# %% [markdown]
# ## **Checking duplicate in the data**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## **Checking statics of the function**

# %%
df.describe()
# Out:
#        AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# count    528.000000       5.280000e+02  5.280000e+02    5.280000e+02
# mean    1492.005871       2.462780e+05  1.252757e+05    1.209841e+05
# std     2039.453778       2.711898e+05  1.375630e+05    1.337169e+05
# min        0.000000       0.000000e+00  0.000000e+00    0.000000e+00
# 25%      425.000000       5.093450e+04  2.712725e+04    2.397900e+04
# 50%      882.000000       1.652410e+05  8.413450e+04    8.204400e+04
# 75%     1734.250000       3.129112e+05  1.605022e+05    1.522190e+05
# max    18374.000000       2.297375e+06  1.172995e+06    1.124167e+06
#
#        TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# count           528.000000         528.000000                  528.000000
# mean             18.174242          98.982614                    6.277064
# std              25.522248          26.812660                    2.074947
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    str
#  1   DIVISION                    528 non-null    str
#  2   DISTRICT                    528 non-null    str
#  3   SUB DIVISION                528 non-null    str
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
print(df.columns.to_list())
# print(df['PROVINCE'].unique().value_counts())
# Out:
# ['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)', 'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)', 'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)', 'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)', 'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)', 'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)', 'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)', 'ANNUAL GROWTH RATE (URBAN)']

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %% [markdown]
# ## **Camparison of all province**

# %%
df['PROVINCE'].value_counts()
# Out:
# PROVINCE
# PUNJAB         143
# SINDH          137
# BALOCHISTAN    131
# KPK             71
# KPK/FATA        46
# Name: count, dtype: int64

# %%
# Number of divisions in each province
number_of_divisions = df.groupby('PROVINCE')['DIVISION'].nunique()
number_of_divisions.sort_values(ascending=False)
# Out:
# PROVINCE
# PUNJAB         9
# SINDH          7
# KPK            7
# BALOCHISTAN    5
# KPK/FATA       5
# Name: DIVISION, dtype: int64

# %%
unique_divisions=df.groupby('PROVINCE')['DIVISION'].nunique()
unique_divisions
# Out:
# PROVINCE
# BALOCHISTAN    5
# KPK            7
# KPK/FATA       5
# PUNJAB         9
# SINDH          7
# Name: DIVISION, dtype: int64

# %%
print(df['PROVINCE'].unique())
# Out:
# <StringArray>
# ['PUNJAB', 'SINDH', 'BALOCHISTAN', 'KPK', 'KPK/FATA']
# Length: 5, dtype: str

# %% [markdown]
# ## **Exploring punjab**

# %%
punjab_data=df[df['PROVINCE']=='PUNJAB']

# %%
punjab_data.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
print(punjab_data['DIVISION'].unique())
# Out:
# <StringArray>
# ['BAHAWALPUR DIVISION',   'D.G.KHAN DIVISION', 'FAISALABAD DIVISION',
#  'GUJRANWALA DIVISION',     'LAHORE DIVISION',     'MULTAN DIVISION',
#  'RAWALPINDI DIVISION',    'SAHIWAL DIVISION',   'SARGODHA DIVISION']
# Length: 9, dtype: str

# %%
punjab_data['DISTRICT'].unique()
# Out:
# <StringArray>
# [   'BAHAWALNAGAR DISTRICT',      'BAHAWALPUR DISTRICT',
#   'RAHIM YAR KHAN DISTRICT', 'DERA GHAZI KHAN DISTRICT',
#           'LAYYAH DISTRICT',    'MUZAFFARGARH DISTRICT',
#         'RAJANPUR DISTRICT',         'CHINIOT DISTRICT',
#       'FAISALABAD DISTRICT',           'JHANG DISTRICT',
#   'TOBA TEK SINGH DISTRICT',      'GUJRANWALA DISTRICT',
#           'GUJRAT DISTRICT',       'HAFIZABAD DISTRICT',
#  'MANDI BAHAUDDIN DISTRICT',         'NAROWAL DISTRICT',
#          'SIALKOT DISTRICT',           'KASUR DISTRICT',
#           'LAHORE DISTRICT',   'NANKANA SAHIB DISTRICT',
#      'SHEIKHUPURA DISTRICT',        'KHANEWAL DISTRICT',
#          'LODHRAN DISTRICT',          'MULTAN DISTRICT',
#           'VEHARI DISTRICT',          'ATTOCK DISTRICT',
#          'CHAKWAL DISTRICT',          'JHELUM DISTRICT',
#       'RAWALPINDI DISTRICT',           'OKARA DISTRICT',
#        'PAKPATTAN DISTRICT',         'SAHIWAL DISTRICT',
# ...

# %%
punjab_data['SUB DIVISION'].unique()
# Out:
# <StringArray>
# [     'BAHAWALNAGAR TEHSIL',         'CHISHTIAN TEHSIL',
#         'FORT ABBAS TEHSIL',        'HAROONABAD TEHSIL',
#        'MINCHINABAD TEHSIL',     'AHMADPUR EAST TEHSIL',
#    'BAHAWALPUR CITY TEHSIL', 'BAHAWALPUR SADDAR TEHSIL',
#           'HASILPUR TEHSIL', 'KHAIRPUR TAMEWALI TEHSIL',
#  ...
#          'QUAIDABAD TEHSIL',           'ISAKHEL TEHSIL',
#           'MIANWALI TEHSIL',            'PIPLAN TEHSIL',
#            'BHALWAL TEHSIL',             'BHERA TEHSIL',
#          'KOT MOMIN TEHSIL',          'SARGODHA TEHSIL',
#            'SHAHPUR TEHSIL',        'SILLANWALI TEHSIL']
# Length: 143, dtype: str

# %%
punjab_data.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
# Area of each district in Punjab
punjab_area = punjab_data.groupby('DISTRICT')['AREA (sq.km)'].sum().reset_index()
punjab_area = punjab_area.sort_values(by='AREA (sq.km)', ascending=False)
punjab_area
# Out:
#                     DISTRICT  AREA (sq.km)
# 2        BAHAWALPUR DISTRICT       24830.0
# 28         RAJANPUR DISTRICT       12318.0
# 6   DERA GHAZI KHAN DISTRICT       11922.0
# 27   RAHIM YAR KHAN DISTRICT       11880.0
# 1      BAHAWALNAGAR DISTRICT        8878.0
# 22     MUZAFFARGARH DISTRICT        8249.0
# 3           BHAKKAR DISTRICT        8153.0
# 0            ATTOCK DISTRICT        6857.0
# 4           CHAKWAL DISTRICT        6525.0
# 15          KHUSHAB DISTRICT        6511.0
# 11            JHANG DISTRICT        6166.0
# 7        FAISALABAD DISTRICT        5857.0
# 20         MIANWALI DISTRICT        5840.0
# 29       RAWALPINDI DISTRICT        5285.0
# 31         SARGODHA DISTRICT        5027.0
# 17           LAYYAH DISTRICT        4466.0
# 25            OKARA DISTRICT        4377.0
# 35           VEHARI DISTRICT        4364.0
# 14         KHANEWAL DISTRICT        4349.0
# 13            KASUR DISTRICT        3995.0
# 32      SHEIKHUPURA DISTRICT        3744.0
# ...

# %%
# Out:
# <Axes: xlabel='DISTRICT', ylabel='AREA (sq.km)'>
